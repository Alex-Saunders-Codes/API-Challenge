# %% [markdown]
# # WeatherPy
# ----

# %%
import pandas as pd
import random
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import requests

# %%
import citipy_c as ct

# %% [markdown]
# Import a custom modification of citipy, stored in my project folders

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# In order to generate cities, I will be creating a random latitude and longitude, and passing them into citipy's nearest_city funtion.

# %% [markdown]
# This method has a dramatic flaw - it will generate cities which massively favor the coastline. While that might be good for looking for a vacation location, it introduces some clear bias in how I analyze the relationship between weather and longitude.

# %% [markdown]
# In order to combat this, I have modified my local version of citipy to include a lat and lng in the class city.

# %%
#A brief lambda function to make my later conditional statements tidier
absCheck = lambda x, y: abs(abs(x) - abs(y))

# %%
#Create a list of dictionairies with data about found cities.
city_list=[]
while len(city_list) < 1200:
    row = {}
    #Generate a random latitude and longitude
    latitude = random.randint(-90,90)
    longitude = random.randint(-180, 180)
    city = ct.nearest_city(latitude, longitude)
    #This will test that the found city is within a 138 by 119 mile rectangle around the test point.
    if (absCheck(city.lat, latitude) <= 1) & (absCheck(city.lng, longitude) <= 1):
        row['name'] = city.city_name
        row['country code'] = city.country_code
        row['lat'] = round(city.lat, 3)
        row['lng'] = round(city.lng, 3)
        city_list.append(row)
#Turn my list of dictionaries into a dataframe.
city_df = pd.DataFrame(data=city_list).drop_duplicates()
print(len(city_df))
city_df.head()
# Out:
# 1108
#              name country code     lat      lng
# 0        menongue           ao -14.662   17.688
# 1            wawa           ca  48.000  -84.783
# 2  sainte-suzanne           re -20.900   55.617
# 3           edson           ca  53.583 -116.417
# 4             fez           ma  34.037   -5.000

# %% [markdown]
# And now a quick scatterplot of the generated cities latitude and longitude, to verify that distribution has worked as intended.

# %%
loc_fig, loc_ax = plt.subplots(figsize=(9,4.5))
loc_ax.set_title('Locations of Generated Cities')
loc_ax.set_xlabel('Longitude')
loc_ax.set_ylabel('Latitude')
loc_ax.set_facecolor('xkcd:ocean blue')
loc_ax.scatter( city_df['lng'], city_df['lat'],color='green', edgecolors='white', alpha=0.6)
plt.show()

# %% [markdown]
# As we can see, distribution is still not quite uniform - there's very few datapoints from areas that are largely uninhabitable, like the sahara desert and the himilayas. This data could be valuable, as all of these represent extreme climates which could challenge models we generate. However, we would likely need to completely rethink our approach to generating datapoints and forgo finding cities alltogether.

# %% [markdown]
# Instead, I will reframe the problem as understanding how latitude affects weather in human habitable environments.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
from api_keys import weather_api_key as wak
import time

# %%
#this function allows me to average different data across a 24 hour period that is returned in the json.
def dayAverages(day, target):
    target_ave = 0
    for hour in day:
        target_ave += hour[target]
    target_ave = target_ave/len(day)
    return round(target_ave,3)

# %%
weather_list = []
for city in city_df.itertuples():
    #I iterate across my dataframe with itertuples.
    #Because I am working with tuples, I pass numberic indices for reference.
    print(f'now printing city #{city[0]}: {city[1]}')
    weather_dict = {}
    lat = city[3]
    lng = city[4]
    #Set time of query to one day ago
    tm = int(time.time() - 86400)
    #define the output units [standard, metric, or imperial]
    units='imperial'
    search_url = f'http://api.openweathermap.org/data/2.5/onecall/timemachine?lat={lat}&lon={lng}&dt={tm}&units={units}&appid={wak}'
    #Query the data from openweathermap
    response = requests.get(search_url).json()
    response
    weather_dict['name'] = city[1]
    #Get an average temperature for all the hours yesterday.
    try:
        targets=['temp', 'humidity', 'clouds', 'wind_speed']
        for target in targets:
            weather_dict[target] = dayAverages(response['hourly'], target)
    except Exception as e:
        print('Operation failed: ' + str(e))
    weather_list.append(weather_dict)
        

weather_df = pd.DataFrame(data=weather_list)
weather_df.head()
# Out:
# now printing city #0: menongue
# now printing city #1: wawa
# now printing city #2: sainte-suzanne
# now printing city #3: edson
# now printing city #4: fez
# now printing city #5: asimion
# now printing city #6: moyale
# now printing city #7: tres picos
# now printing city #8: zigong
# now printing city #9: mangan
# now printing city #10: campbell river
# now printing city #11: zhob
# now printing city #12: poronaysk
# now printing city #13: ortigueira
# now printing city #14: malindi
# now printing city #15: alcaniz
# now printing city #16: namtsy
# now printing city #17: stoyba
# now printing city #18: holetown
# now printing city #19: hunza
# now printing city #20: leticia
# now printing city #21: sedkyrkeshch
# now printing city #22: alta floresta
# now printing city #23: hay river
# now printing city #24: arraial do cabo
# now printing city #25: ask
# now printing city #26: omura
# now printing city #27: matinha
# now printing city #28: is
# now printing city #29: south yuba city
# now printing city #30: lewisporte
# now printing city #31: bulgan
# now printing city #32: carlos chagas
# now printing city #33: tunxi
# now printing city #34: inyonga
# now printing city #35: benoy
# now printing city #36: kalevala
# now printing city #37: mbanza-ngungu
# now printing city #38: bronnoysund
# now printing city #39: ikom
# now printing city #40: krasnokholmskiy
# now printing city #41: ziro
# now printing city #42: znamenskoye
# now printing city #43: teresina
# now printing city #44: rocky mountain house
# now printing city #45: santa maria del oro
# now printing city #46: sao paulo de olivenca
# now printing city #47: bela vista
# now printing city #48: severo-kurilsk
# now printing city #49: puerto del rosario
# now printing city #50: kiunga
# now printing city #51: uyskoye
# now printing city #52: praia
# now printing city #53: shirokiy
# now printing city #54: huangmei
# now printing city #55: nha trang
# now printing city #56: suntar
# now printing city #57: kemin
# now printing city #58: sao gotardo
# now printing city #59: minot
# now printing city #60: betioky
# now printing city #61: khani
# now printing city #62: topeka
# now printing city #63: tabory
# now printing city #64: banff
# now printing city #65: dingle
# now printing city #66: khasan
# now printing city #67: itoman
# now printing city #68: starosubkhangulovo
# now printing city #69: kermanshah
# now printing city #70: pleasanton
# now printing city #71: port hardy
# now printing city #72: navirai
# now printing city #73: chipinge
# now printing city #74: gao
# now printing city #75: tiruvottiyur
# now printing city #76: yongan
# now printing city #77: fianarantsoa
# now printing city #78: loandjili
# now printing city #79: tiassale
# now printing city #80: impfondo
# now printing city #81: lesnoy
# now printing city #82: baraki barak
# now printing city #83: gimli
# now printing city #84: miranda
# now printing city #85: porciuncula
# now printing city #86: zhanaozen
# now printing city #87: yarkovo
# now printing city #88: vila franca do campo
# now printing city #89: ginda
# now printing city #90: kearney
# now printing city #91: starachowice
# now printing city #92: vagamo
# now printing city #93: port keats
# now printing city #94: manyana
# now printing city #95: staryy saltiv
# now printing city #96: tambacounda
# now printing city #97: sonoita
# now printing city #98: dubti
# now printing city #218: mount gambier
# now printing city #219: aitape
# now printing city #220: orizona
# now printing city #221: paamiut
# now printing city #222: alakurtti
# now printing city #223: kasongo-lunda
# now printing city #224: muhos
# now printing city #225: spartanburg
# now printing city #226: madinat sittah uktubar
# now printing city #227: paso de carrasco
# now printing city #228: sooke
# now printing city #229: qaqortoq
# now printing city #231: cache creek
# now printing city #232: maniitsoq
# now printing city #233: diapaga
# now printing city #234: tucuma
# now printing city #236: nimaparha
# now printing city #237: rovaniemi
# now printing city #238: paoua
# now printing city #239: curuca
# now printing city #240: pietarsaari
# now printing city #241: dromolaxia
# now printing city #242: valley city
# now printing city #243: katherine
# now printing city #244: prince rupert
# now printing city #245: antigonish
# now printing city #246: ivnya
# now printing city #247: ust-kamchatsk
# now printing city #248: barcelona
# now printing city #249: copperas cove
# now printing city #250: altamira
# now printing city #251: hendaye
# now printing city #252: limbang
# now printing city #254: shieli
# now printing city #255: laurel
# now printing city #256: dharchula
# now printing city #257: nuevo progreso
# now printing city #258: gawler
# now printing city #259: rockhampton
# now printing city #260: linguere
# now printing city #261: vaitape
# now printing city #262: goldsboro
# now printing city #263: batken
# now printing city #264: ruteng
# now printing city #266: alihe
# now printing city #267: longyearbyen
# now printing city #268: pyinmana
# now printing city #269: lyaskelya
# now printing city #270: dongying
# now printing city #271: lubao
# now printing city #272: san fernando
# now printing city #273: taburao
# now printing city #274: juneau
# now printing city #275: san patricio
# now printing city #276: igrim
# now printing city #277: yubari
# now printing city #278: paysandu
# now printing city #279: terme
# now printing city #280: marietta
# now printing city #281: port hedland
# now printing city #282: dingzhou
# now printing city #283: tias
# now printing city #284: saskatoon
# now printing city #285: datong
# now printing city #286: kavaratti
# now printing city #287: vila
# now printing city #288: azimur
# now printing city #289: yarmouth
# now printing city #290: kuytun
# now printing city #291: sao joao do paraiso
# now printing city #292: kampene
# now printing city #293: bhag
# now printing city #294: myre
# now printing city #295: fuyang
# now printing city #296: ostrovskoye
# now printing city #297: lady lake
# now printing city #299: aztec
# now printing city #300: atbasar
# now printing city #301: chingola
# now printing city #302: puqi
# now printing city #303: bom jesus
# now printing city #304: kurara
# now printing city #305: san cristobal
# now printing city #306: amazar
# now printing city #307: malbork
# now printing city #308: mushie
# now printing city #309: zyryanskoye
# now printing city #310: saint-jean-port-joli
# now printing city #311: filingue
# now printing city #312: subate
# now printing city #313: esna
# now printing city #314: truro
# now printing city #315: eldikan
# now printing city #316: roblin
# now printing city #317: rodrigues alves
# now printing city #318: minas
# now printing city #319: ilebo
# now printing city #320: bandar-e torkaman
# now printing city #321: niquero
# now printing city #322: betanzos
# now printing city #323: toyooka
# now printing city #324: cerrito
# now printing city #325: suoyarvi
# now printing city #326: kropotkin
# now printing city #327: helsinki
# now printing city #328: pingliang
# now printing city #329: gladstone
# now printing city #330: aksarka
# now printing city #331: chilliwack
# now printing city #332: kainantu
# now printing city #333: bolshoy uluy
# now printing city #334: yokadouma
# now printing city #335: tilichiki
# now printing city #336: yagodnoye
# now printing city #337: capoterra
# now printing city #582: vysokogornyy
# now printing city #583: grand-lahou
# now printing city #584: srednekolymsk
# now printing city #585: panaba
# now printing city #586: monteiro
# now printing city #587: vidim
# now printing city #588: boulder
# now printing city #590: makung
# now printing city #591: artyom
# now printing city #592: manokwari
# now printing city #593: grootfontein
# now printing city #594: socorro
# now printing city #595: rjukan
# now printing city #598: turukhansk
# now printing city #599: lindi
# now printing city #600: luau
# now printing city #601: la baneza
# now printing city #602: astipalaia
# now printing city #603: ragama
# now printing city #604: muswellbrook
# now printing city #605: la paz
# now printing city #606: angoram
# now printing city #607: djibo
# now printing city #608: san martin
# now printing city #609: boras
# now printing city #610: curup
# now printing city #611: atakpame
# now printing city #612: kodino
# now printing city #614: muzhi
# now printing city #615: walla walla
# now printing city #617: fernandez
# now printing city #618: manali
# now printing city #619: zlatoustovsk
# now printing city #621: marystown
# now printing city #622: alamosa
# now printing city #623: kourou
# now printing city #624: yumen
# now printing city #625: mayumba
# now printing city #626: katete
# now printing city #627: pundaguitan
# now printing city #628: chodziez
# now printing city #629: clinton
# now printing city #630: elizabeth city
# now printing city #632: nerchinskiy zavod
# now printing city #634: ayame
# now printing city #635: sibut
# now printing city #636: nayudupeta
# now printing city #637: ceuta
# now printing city #638: fort saint james
# now printing city #639: kidal
# now printing city #640: cururupu
# now printing city #641: amarante do maranhao
# now printing city #642: martapura
# now printing city #643: heishan
# now printing city #644: ust-maya
# now printing city #646: jatara
# now printing city #648: diamantina
# now printing city #649: sanchor
# now printing city #650: rexburg
# now printing city #651: valparaiso
# now printing city #653: maun
# now printing city #654: cedar rapids
# now printing city #655: dunmore east
# now printing city #656: changping
# now printing city #657: kragujevac
# now printing city #658: ingham
# now printing city #659: jhikargachha
# now printing city #660: vadso
# now printing city #661: powell river
# now printing city #662: taber
# now printing city #663: jever
# now printing city #664: collie
# now printing city #665: novaya igirma
# now printing city #666: sargatskoye
# now printing city #667: dossor
# now printing city #668: bogandinskiy
# now printing city #669: mnogovershinnyy
# now printing city #670: sinkat
# now printing city #671: powell
# now printing city #672: kytlym
# now printing city #673: barawe
# now printing city #674: stolin
# now printing city #675: hagere hiywet
# now printing city #677: gollere
# now printing city #678: alberton
# now printing city #679: paramirim
# now printing city #680: mortka
# now printing city #682: valjala
# now printing city #683: sao marcos
# now printing city #684: colorado springs
# now printing city #685: vicksburg
# now printing city #686: grants
# now printing city #687: oranjemund
# now printing city #688: illoqqortoormiut
# now printing city #689: bam
# now printing city #691: hanmer springs
# now printing city #692: jertih
# now printing city #694: maicao
# now printing city #695: kampot
# now printing city #696: guider
# now printing city #697: adrar
# now printing city #698: skjervoy
# now printing city #699: santa maria da vitoria
# now printing city #700: ruatoria
# now printing city #701: durango
# now printing city #702: dir
# now printing city #703: teya
# now printing city #705: mwene-ditu
# now printing city #706: sakaraha
# now printing city #707: ranau
# now printing city #708: kitob
# now printing city #709: bafoulabe
# now printing city #710: loutrakion
# now printing city #711: mosquera
# now printing city #712: atuona
# now printing city #714: gizo
# now printing city #715: dinsor
# now printing city #716: ibiapina
# now printing city #717: faanui
# now printing city #719: taveta
# now printing city #720: gorontalo
# now printing city #721: tynda
# now printing city #722: geraldton
# now printing city #723: tra vinh
# now printing city #724: fairlie
# now printing city #725: columbus
# now printing city #727: lanivtsi
# now printing city #728: lydenburg
# now printing city #729: pevek
# now printing city #730: talavera de la reina
# now printing city #731: devils lake
# now printing city #732: aranos
# now printing city #733: lao cai
# now printing city #734: fairview
# now printing city #735: hvammstangi
# now printing city #737: rosario
# now printing city #738: crixas
# now printing city #739: busayra
# now printing city #740: lichtenburg
# now printing city #741: san lawrenz
# now printing city #742: ridgecrest
# now printing city #743: phuntsholing
# now printing city #744: lusambo
# now printing city #745: lokosovo
# now printing city #747: achisay
# now printing city #748: kaunas
# now printing city #750: deputatskiy
# now printing city #751: tsybuliv
# now printing city #754: campoverde
# now printing city #755: kondinskoye
# now printing city #756: brazzaville
# now printing city #757: tabialan
# now printing city #758: brandon
# now printing city #760: ilhabela
# now printing city #761: teeli
# now printing city #762: chitral
# now printing city #763: roros
# now printing city #764: bukachacha
# now printing city #765: sembe
# now printing city #766: vilhena
# now printing city #767: marigot
# now printing city #768: nikki
# now printing city #769: rahon
# now printing city #770: raduzhnyy
# now printing city #771: elko
# now printing city #772: sofiysk
# now printing city #773: aklavik
# now printing city #774: findochty
# now printing city #775: chany
# now printing city #776: narsaq
# now printing city #777: richard toll
# now printing city #778: sucre
# now printing city #779: cambrai
# now printing city #780: vardo
# now printing city #782: taitung
# now printing city #783: jiayuguan
# now printing city #784: vikyrovice
# now printing city #785: florida
# now printing city #786: zhigansk
# now printing city #787: stilling
# now printing city #788: vanino
# now printing city #789: sebina
# now printing city #791: chunian
# now printing city #792: zhengjiatun
# now printing city #793: turmalina
# now printing city #794: vaitupu
# now printing city #795: liberal
# now printing city #796: polson
# now printing city #797: gallup
# now printing city #798: aleksandrovsk-sakhalinskiy
# now printing city #799: dalby
# now printing city #800: toliary
# now printing city #801: perevolotskiy
# now printing city #802: orocue
# now printing city #803: petrovskoye
# now printing city #804: dunda
# now printing city #805: virginia beach
# now printing city #806: litovko
# now printing city #807: xapuri
# now printing city #809: crib point
# now printing city #810: gofitskoye
# now printing city #811: bafra
# now printing city #812: palaiokhora
# now printing city #813: sumbe
# now printing city #815: dekar
# now printing city #816: yurga
# now printing city #817: sembakung
# now printing city #819: ginir
# now printing city #820: uniontown
# now printing city #822: kilmez
# now printing city #823: umba
# now printing city #825: srivardhan
# now printing city #826: bolshaya murta
# now printing city #827: luganville
# now printing city #829: guozhen
# now printing city #830: kigoma
# now printing city #831: hoyanger
# now printing city #832: kuching
# now printing city #833: nizhniy odes
# now printing city #834: nova serrana
# now printing city #835: tyukalinsk
# now printing city #836: nevsehir
# now printing city #837: villa bruzual
# now printing city #838: manalurpet
# now printing city #839: selkirk
# now printing city #840: salme
# now printing city #841: humaita
# now printing city #842: kotma
# now printing city #843: karauzyak
# now printing city #844: kilimatinde
# now printing city #845: abu kamal
# now printing city #846: jaciara
# now printing city #847: kupino
# now printing city #848: aconibe
# now printing city #849: akkermanovka
# now printing city #850: nanaimo
# now printing city #851: ponte de sor
# now printing city #852: mergui
# now printing city #853: mrirt
# now printing city #855: kedrovyy
# now printing city #856: marathon
# now printing city #857: mahon
# now printing city #858: farrukhnagar
# now printing city #859: mackenzie
# now printing city #860: provideniya
# now printing city #861: guerrero negro
# now printing city #862: putyatino
# now printing city #863: mooi river
# now printing city #864: canutama
# now printing city #866: noumea
# now printing city #867: davidson
# now printing city #869: rundu
# now printing city #870: fourmies
# now printing city #871: bagdarin
# now printing city #872: nueva loja
# now printing city #873: tawang
# now printing city #874: zalantun
# now printing city #875: tabas
# now printing city #876: khatra
# now printing city #877: fernie
# now printing city #878: tucuman
# now printing city #879: sindand
# now printing city #880: carnarvon
# now printing city #881: little current
# now printing city #882: pangody
# now printing city #883: port-de-paix
# now printing city #884: almaty
# now printing city #885: bayangol
# now printing city #886: nyrad
# now printing city #887: san jose
# now printing city #888: cape town
# now printing city #889: temaraia
# now printing city #890: karakose
# now printing city #891: joao pinheiro
# now printing city #892: nguru
# now printing city #893: avarua
# now printing city #894: tete
# now printing city #895: ambikapur
# now printing city #896: voghera
# now printing city #897: maksatikha
# now printing city #899: macklin
# now printing city #900: poum
# now printing city #902: gorele
# now printing city #904: pingxiang
# now printing city #905: puerto castilla
# now printing city #906: itapora
# now printing city #907: hong gai
# now printing city #908: senanga
# now printing city #909: ust-barguzin
# now printing city #910: veshkayma
# now printing city #911: miami
# now printing city #912: magadi
# now printing city #913: ariquemes
# now printing city #914: belaya glina
# now printing city #915: shevchenkove
# now printing city #916: barra do bugres
# now printing city #917: mogok
# now printing city #918: grenada
# now printing city #919: la plata
# now printing city #920: huejuquilla el alto
# now printing city #921: rawah
# now printing city #923: kurilsk
# now printing city #924: devrek
# now printing city #925: shintomi
# now printing city #926: lewiston
# now printing city #927: ojinaga
# now printing city #928: shkotovo-22
# now printing city #929: veliki preslav
# now printing city #930: akdepe
# now printing city #931: gamba
# now printing city #932: braganca
# now printing city #933: mirnyy
# now printing city #934: salalah
# now printing city #936: barentsburg
# now printing city #937: sriperumbudur
# now printing city #938: shihezi
# now printing city #939: san ramon
# now printing city #940: kushiro
# now printing city #942: alekseyevka
# now printing city #943: sesheke
# now printing city #944: ponta do sol
# now printing city #945: bengkulu
# now printing city #946: gazojak
# now printing city #947: ust-kut
# now printing city #948: blagoveshchenka
# now printing city #949: murray bridge
# now printing city #950: ocho rios
# now printing city #951: winston
# now printing city #952: saint-michel-des-saints
# now printing city #953: san ramon
# now printing city #955: aden
# now printing city #956: castlemaine
# now printing city #957: hays
# now printing city #958: paytug
# now printing city #959: oksfjord
# now printing city #960: albany
# now printing city #961: koslan
# now printing city #963: bafq
# now printing city #964: ostersund
# now printing city #965: palimbang
# now printing city #966: carnarvon
# now printing city #968: nikolskoye
# now printing city #969: loreto
# now printing city #971: eten
# now printing city #972: votkinsk
# now printing city #974: gualaco
# now printing city #975: campo maior
# now printing city #976: puerto colombia
# now printing city #977: sabha
# now printing city #978: mabaruma
# now printing city #979: sept-iles
# now printing city #980: jingdezhen
# now printing city #981: stafford
# now printing city #982: ossora
# now printing city #983: worland
# now printing city #984: pouso alegre
# now printing city #985: mehamn
# now printing city #986: murindo
# now printing city #988: onokhoy
# now printing city #989: rossland
# now printing city #990: dzhusaly
# now printing city #991: yuza
# now printing city #992: bandiagara
# now printing city #993: rafina
# now printing city #994: roswell
# now printing city #995: lesogorsk
# now printing city #996: korla
# now printing city #997: lumajang
# now printing city #999: kralendijk
# now printing city #1000: jatibonico
# now printing city #1001: hungund
# now printing city #1002: santa isabel do rio negro
# now printing city #1003: nyimba
# now printing city #1004: buenavista
# now printing city #1005: lamar
# now printing city #1006: sebastian
# now printing city #1007: nedjo
# now printing city #1008: klaksvik
# now printing city #1009: port blair
# now printing city #1010: kysyl-syr
# now printing city #1011: jackson
# now printing city #1012: takob
# now printing city #1013: meilu
# now printing city #1014: bur gabo
# now printing city #1015: ovalle
# now printing city #1016: umm lajj
# now printing city #1017: fredericton
# now printing city #1018: berbera
# now printing city #1019: tommot
# now printing city #1020: cabanas
# now printing city #1021: muslyumovo
# now printing city #1022: tarsus
# now printing city #1023: pousat
# now printing city #1024: libano
# now printing city #1025: doba
# now printing city #1026: krasnoselkup
# now printing city #1027: brunsbuttel
# now printing city #1028: kichera
# now printing city #1029: toba
# now printing city #1030: blackwater
# now printing city #1031: junin
# now printing city #1032: blackfoot
# now printing city #1033: proti
# now printing city #1034: cap malheureux
# now printing city #1035: casper
# now printing city #1036: cap-haitien
# now printing city #1037: kawambwa
# now printing city #1039: burnie
# now printing city #1040: russellville
# now printing city #1041: hilo
# now printing city #1042: yarada
# now printing city #1043: ust-bolsheretsk
# now printing city #1044: verkh-usugli
# now printing city #1045: maloy
# now printing city #1046: batie
# now printing city #1047: chara
# now printing city #1048: south lake tahoe
# now printing city #1049: wloszczowa
# now printing city #1050: nizamabad
# now printing city #1051: fairfield
# now printing city #1052: pauri
# now printing city #1053: manicore
# now printing city #1054: primore
# now printing city #1055: nalvo
# now printing city #1056: prieska
# now printing city #1057: amapa
# now printing city #1058: caranavi
# now printing city #1059: leningradskiy
# now printing city #1060: karatuzskoye
# now printing city #1061: krasnorechenskiy
# now printing city #1062: santa ana
# now printing city #1063: dosso
# now printing city #1064: jiwani
# now printing city #1065: lodwar
# now printing city #1068: kamaishi
# now printing city #1069: zhoucheng
# now printing city #1071: podgornoye
# now printing city #1072: poim
# now printing city #1073: bayan
# now printing city #1074: verkhnevilyuysk
# now printing city #1075: montanha
# now printing city #1076: merke
# now printing city #1079: cananeia
# now printing city #1080: phuket
# now printing city #1081: armizonskoye
# now printing city #1082: saint george
# now printing city #1083: bhaderwah
# now printing city #1084: si bun ruang
# now printing city #1085: kovdor
# now printing city #1086: tursunzoda
# now printing city #1087: grand centre
# now printing city #1088: balakovo
# now printing city #1089: dembi dolo
# now printing city #1090: abnub
# now printing city #1091: kuche
# now printing city #1092: semporna
# now printing city #1095: felanitx
# now printing city #1097: dourbali
# now printing city #1098: khirkiya
# now printing city #1099: chimore
# now printing city #1100: kuala lipis
# now printing city #1101: hofn
# now printing city #1102: belgrade
# now printing city #1103: sabinas
# now printing city #1105: kizema
# now printing city #1106: sun city west
# now printing city #1107: savelugu
# now printing city #1108: culipapa
# now printing city #1109: qandahar
# now printing city #1110: jahrom
# now printing city #1111: brigantine
# now printing city #1112: aberdeen
# now printing city #1113: kumluca
# now printing city #1114: juquitiba
# now printing city #1115: san luis
# now printing city #1116: simao
# now printing city #1117: teneguiban
# now printing city #1118: ledyard
# now printing city #1119: oktyabrskoye
# now printing city #1120: erhlin
# now printing city #1121: blensong
# now printing city #1123: leskovac
# now printing city #1124: birecik
# now printing city #1125: shestakovo
# now printing city #1126: maykain
# now printing city #1127: garmsar
# now printing city #1128: dunmore town
# now printing city #1129: leczyca
# now printing city #1130: pervomayskoye
# now printing city #1131: constanza
# now printing city #1132: olonets
# now printing city #1133: bossembele
# now printing city #1134: villazon
# now printing city #1135: kalaleh
# now printing city #1137: tera
# now printing city #1138: ankara
# now printing city #1139: pozoblanco
# now printing city #1140: molchanovo
# now printing city #1141: kibondo
# now printing city #1142: gaoual
# now printing city #1143: curaca
# now printing city #1144: salamiyah
# now printing city #1145: guajara
# now printing city #1146: cockburn harbour
# now printing city #1148: arroio grande
# now printing city #1149: longview
# now printing city #1150: susner
# now printing city #1151: yei
# now printing city #1152: simpang
# now printing city #1153: villa guerrero
# now printing city #1154: aleksandrov gay
# now printing city #1155: kenora
# now printing city #1157: sonepur
# now printing city #1159: high prairie
# now printing city #1161: rzeszow
# now printing city #1162: ketchikan
# now printing city #1163: cabudare
# now printing city #1164: hermiston
# now printing city #1165: tuapse
# now printing city #1166: kracheh
# now printing city #1167: koumac
# now printing city #1168: nara
# now printing city #1169: terra roxa
# now printing city #1170: tessaoua
# now printing city #1171: barrow
# now printing city #1173: sinop
# now printing city #1175: bluefields
# now printing city #1176: xai-xai
# now printing city #1177: mujiayingzi
# now printing city #1178: urdzhar
# now printing city #1179: heyang
# now printing city #1180: sinait
# now printing city #1182: ifo
# now printing city #1184: cao bang
# now printing city #1185: vangaindrano
# now printing city #1186: pedasi
# now printing city #1188: kursenai
# now printing city #1189: cartagena del chaira
# now printing city #1190: san mariano
# now printing city #1191: rincon
# now printing city #1192: tsimlyansk
# now printing city #1193: koulamoutou
# now printing city #1194: troitskiy
# now printing city #1196: el faiyum
# now printing city #1197: anqing
# now printing city #1198: dolbeau
# now printing city #1199: jutai
#              name       temp   humidity     clouds  wind_speed
# 0        menongue  59.600417  28.500000   0.000000    5.144583
# 1            wawa  61.703333  68.375000  21.000000    4.986250
# 2  sainte-suzanne  67.718750  75.416667  56.041667   18.460833
# 3           edson  64.175000  62.583333  26.500000    7.240417
# 4             fez  96.567917  12.666667  33.291667    8.680833

# %%
len(weather_df)
# Out:
# 1108

# %%
weather_df_2 = weather_df.merge(city_df, on='name', how = 'outer')
weather_df_2.iloc[:,1:5] = weather_df_2.iloc[:,1:5].apply(lambda x: round(x,3))

# %%
#Save the data to a csv
weather_df_2.to_csv('Results/weather_data.csv', index=False)

# %%
weather_df_2.head()
# Out:
#              name    temp  humidity  clouds  wind_speed country code     lat  \
# 0        menongue  59.600    28.500   0.000       5.145           ao -14.662
# 1            wawa  61.703    68.375  21.000       4.986           ca  48.000
# 2  sainte-suzanne  67.719    75.417  56.042      18.461           re -20.900
# 3           edson  64.175    62.583  26.500       7.240           ca  53.583
# 4             fez  96.568    12.667  33.292       8.681           ma  34.037
#
#        lng
# 0   17.688
# 1  -84.783
# 2   55.617
# 3 -116.417
# 4   -5.000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
len(weather_df_2.loc[weather_df_2['humidity'] > 100])
# Out:
# 0

# %% [markdown]
# There are no cities in my dataframe which have a humidity of over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Temperature across Latitude')
ax1.set_xlabel('Latitude')
ax1.set_ylabel('Degrees(F))')
ax1.set_facecolor('#FAFAFA')
plt.grid(alpha=0.2)
ax1.scatter(weather_df_2['lat'], weather_df_2['temp'], edgecolor="black", alpha = 0.8)
plt.show()
fig1.savefig('Results/TemperaturevsLatitude.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig2, ax2 = plt.subplots()
ax2.set_title('Humidity across Latitude')
ax2.set_xlabel('Latitude')
ax2.set_ylabel('Humidity')
ax2.set_facecolor('#FAFAFA')
plt.grid(alpha=0.2)
ax2.scatter(weather_df_2['lat'], weather_df_2['humidity'], edgecolor="black", color='lightgreen', alpha = 0.8)
plt.show()
fig2.savefig('Results/HumidityvsLatitude.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig3, ax3 = plt.subplots()
ax3.set_title('Cloudiness across Latitude')
ax3.set_xlabel('Latitude')
ax3.set_ylabel('Cloudiness')
ax3.set_facecolor('#FAFAFA')
plt.grid(alpha=0.2)
ax3.scatter(weather_df_2['lat'], weather_df_2['clouds'], edgecolor="black", color='darkgrey', alpha = 0.8)
plt.show()
fig3.savefig('Results/CloudinessvsLatitude.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig3, ax3 = plt.subplots()
ax3.set_title('Wind Speed across Latitude')
ax3.set_xlabel('Latitude')
ax3.set_ylabel('Wind Speed')
ax3.set_facecolor('#FAFAFA')
plt.grid(alpha=0.2)
ax3.scatter(weather_df_2['lat'], weather_df_2['wind_speed'], edgecolor="black", color='lightblue', alpha = 0.8)
plt.show()
fig3.savefig('Results/WindvsLatitude.png')

# %% [markdown]
# ### Temperature Plotted Across a Globe

# %%
fig4, ax4 = plt.subplots(figsize=(18,7.5))
ax4.set_title('Temperature varied across latitude and longitude', weight='bold', size=17)
ax4.set_xlabel('longitude', size=14)
ax4.set_ylabel('latitude', size=14)
ax4.set_facecolor('#fafafa')
ax4.scatter(weather_df_2['lng'], weather_df_2['lat'], edgecolor="black", c=weather_df_2['temp'], cmap = 'inferno', s=70, alpha = 0.7)
normal = matplotlib.colors.Normalize(vmin=weather_df_2['temp'].min(), vmax=weather_df_2['temp'].max())
cbar = fig4.colorbar(cm.ScalarMappable(norm=normal, cmap='inferno'), ax=ax4)
cbar.set_label('Temperature(F)', rotation=90, size=14)
plt.show()
fig4.savefig('Results/TemperatureWorld.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
